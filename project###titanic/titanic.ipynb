# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns

# %%
main=pd.read_csv("gender_submission.csv")
test=pd.read_csv("test.csv")
train=pd.read_csv("train.csv")

# %%
main
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
import missingno as m

# %%
m.bar(train,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
len(main),len(train),len(test)
# Out:
# (418, 891, 418)

# %%
train.shape
# Out:
# (891, 12)

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                  Name   Sex  \
# count    891.000000  891.000000  891.000000                   891   891
# unique          NaN         NaN         NaN                   891     2
# top             NaN         NaN         NaN  Marechal, Mr. Pierre  male
# freq            NaN         NaN         NaN                     1   577
# mean     446.000000    0.383838    2.308642                   NaN   NaN
# std      257.353842    0.486592    0.836071                   NaN   NaN
# min        1.000000    0.000000    1.000000                   NaN   NaN
# 25%      223.500000    0.000000    2.000000                   NaN   NaN
# 50%      446.000000    0.000000    3.000000                   NaN   NaN
# 75%      668.500000    1.000000    3.000000                   NaN   NaN
# max      891.000000    1.000000    3.000000                   NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare        Cabin  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
train.isnull().values.any()
# Out:
# True

# %%
f=train.isnull().sum()
f
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
train.isnull().count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          891
# Embarked       891
# dtype: int64

# %%
o=train.isnull().sum()/train.isnull().count()
o
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
x=f
y=o
j=pd.concat([x,y],axis=1,keys=['total','percent'])
j
# Out:
#              total   percent
# PassengerId      0  0.000000
# Survived         0  0.000000
# Pclass           0  0.000000
# Name             0  0.000000
# Sex              0  0.000000
# Age            177  0.198653
# SibSp            0  0.000000
# Parch            0  0.000000
# Ticket           0  0.000000
# Fare             0  0.000000
# Cabin          687  0.771044
# Embarked         2  0.002245

# %%
plt.subplots(figsize=(14,6))
sns.barplot(j.index,j['percent'])
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='percent'>

# %%
plt.style.use('default') 
total=train.isnull().sum()
perc=train.isnull().sum()/train.isnull().count()
x=pd.concat([total,perc],axis=1,keys=['total', 'percent'])
ax = plt.subplots(figsize=(12, 6))

sns.barplot(x=x.index,y=x['percent'])
plt.xlabel('feature',fontsize=12)
plt.ylabel('percent',fontsize=14)
plt.title('% of missing data',fontsize=17)
plt.show()

# %%
plt.style.use('default')
total=train.isnull().sum()
perc=train.isnull().sum() / train.isnull().count()
total
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
perc
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
train.isnull().count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          891
# Embarked       891
# dtype: int64

# %%
f=pd.concat([total,perc],axis=1,keys=['total','perc'])
f
# Out:
#              total      perc
# PassengerId      0  0.000000
# Survived         0  0.000000
# Pclass           0  0.000000
# Name             0  0.000000
# Sex              0  0.000000
# Age            177  0.198653
# SibSp            0  0.000000
# Parch            0  0.000000
# Ticket           0  0.000000
# Fare             0  0.000000
# Cabin          687  0.771044
# Embarked         2  0.002245

# %%
x=f.index
x
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
y=f['perc']
y
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# Name: perc, dtype: float64

# %%
plt.subplots(figsize=(10,6))
sns.barplot(x,y)
plt.xlabel('feature',fontsize=12)
plt.title(' % of missing data on feature')
plt.legend(loc=2,frameon=True,title='gjhgjhg')
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
m.bar(test,figsize=(10,6),color='y')
# Out:
# <AxesSubplot:>

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
m.heatmap(train,figsize=(8,5))
# Out:
# <AxesSubplot:>

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
m.heatmap(test,figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
m.matrix(train)
# Out:
# <AxesSubplot:>

# %% [raw]
# m.matrix(test)

# %% [markdown]
# m.matrix(test)

# %%
m.matrix(test)
# Out:
# <AxesSubplot:>

# %%
train['Age'].isnull().sum()
# Out:
# 177

# %%
train['Age'].fillna(train['Age'].median(),inplace=True)

# %%
train['Age'].isnull().sum()
# Out:
# 0

# %%
test['Age'].fillna(test['Age'].mean(),inplace=True)

# %%
test['Age'].isnull().sum()
# Out:
# 0

# %%
train['Cabin'].fillna('unknown',inplace=True)
test['Cabin'].fillna('unknown',inplace=True)
train['Embarked'].fillna('unknown')
test['Fare'].fillna(test['Fare'].mean(),inplace=True)

# %%
m.bar(train)
# Out:
# <AxesSubplot:>

# %%
m.bar(test)
# Out:
# <AxesSubplot:>

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(train['Survived'])
plt.xticks(np.arange(2),['dead','survived'])
print(train['Survived'].value_counts())
labels=train['Survived'].value_counts()
for i, k in enumerate(labels):
    plt.text(i, k-77, str(k), horizontalalignment = 'center', size = 14, color = 'black', fontweight = 'bold')
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
test.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare    Cabin  \
# ...

# %%
plt.subplots(figsize=(15,6))
sns.countplot(test['Sex'])
labels=test['Sex'].value_counts()
print(labels)
for i,v in enumerate(labels):
    plt.text(i,v-77,str(v),horizontalalignment='center',color='w',fontsize=22,fontweight='bold')
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
sns.catplot(x='Sex',col='Survived',kind='count',data=train,)

# %%
train.groupby(['Survived','Sex']).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Survived Sex
# 0        female           81      81    81   81     81     81      81    81
#          male            468     468   468  468    468    468     468   468
# 1        female          233     233   233  233    233    233     233   233
#          male            109     109   109  109    109    109     109   109
#
#                  Cabin  Embarked
# Survived Sex
# 0        female     81        81
#          male      468       468
# 1        female    233       231
#          male      109       109

# %%
train['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
sns.countplot(x='Pclass',hue='Survived',data=train)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.catplot(x='Survived',col='Pclass',kind='count',data=train)

# %%
plt.subplots(figsize=(10,6))
sns.barplot('Pclass','Survived',hue='Sex',data=train,linewidth=2,edgecolor=(1,1,1))
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot('Pclass','Survived',hue='Sex',data=train)
labels=train['Sex'].value_counts()
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('Pclass','Survived',kind='point',data=train)
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(train.loc[train['Survived']==0,"Pclass"],shade='True',label='dead')
sns.kdeplot(train.loc[train['Survived']==1,"Pclass"],shade='True',color='r',label='not')
labels=[1,2,3]
plt.xticks(sorted(train.Pclass.unique()),labels)
plt.legend()

# %%
sorted(train.Pclass.unique())
# Out:
# [1, 2, 3]

# %%
sns.distplot(train.Age)
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.subplots(figsize=(8,6))
sns.distplot(train.Age)
plt.title('Distrubution of passengers age (all data)',fontsize= 14)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
bins = [ 0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
train['AgeGroup'] = pd.cut(train["Age"], bins, labels = labels)

# %%
sns.barplot(x="AgeGroup", y="Survived", data=train,ci=None)
plt.show()

# %%
train['Title']=train['Name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]
train['Title']
# Out:
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
#        ...
# 886      Rev
# 887     Miss
# 888     Miss
# 889       Mr
# 890       Mr
# Name: Title, Length: 891, dtype: object

# %%
plt.subplots(figsize=(11,6))
sns.countplot('Title',data=train)
plt.xticks(rotation=45,horizontalalignment='right')
x=train['Title'].value_counts()
for i,v in enumerate(x):
    plt.text(i,v+12,str(v),horizontalalignment='center',fontweight='light',color='b')
# Out:
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax = sns.countplot( x = 'Title', data = train, palette = "hls", order = train['Title'].value_counts().index)
_ = plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light')

# %%
sns.heatmap(train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-3ee685ec34d9> in <module>
# ----> 1 sns.heatmap(train)
#
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\sys\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...
